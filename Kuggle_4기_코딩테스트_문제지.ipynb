# %% [markdown]
# # Q1.
# ### (10점)
# 'word'에서 각 단어의 길이가 홀수인 것만 리스트에 저장해주세요.

# %%
word = ['commonplace', 'cummulative', 'annals', 'blunder', 'injunction', 'irony',
       'sympathy', 'register', 'reclaim', 'apparent', 'requirement', 'dependence',
       'vindicate', 'protection', 'confess', 'covering', 'enrich', 'contemplate']

# %%
# Code here

# %% [markdown]
# # Q2.
# ### (10점)
# 빈 리스트 a,b 가 있습니다. 0~9의 숫자 중 짝수는 a 리스트에, 홀수는 b 리스트에 들어가도록 만드세요.(0은 짝수라 가정)

# %%
# Code here

# %% [markdown]
# # Q3.
# ### (20점)
# 두 개의 정수를 계속해서 입력 받아서 두 수의 차를 출력하는 프로그램을 만들어 주세요.
#
# * 무조건 큰 수에서 작은 수를 뺀 결과를 출력해야 합니다. (입력된 순서는 어떤 것이 클 지 모릅니다.)

# %%
# Code here

# %% [markdown]
# # Q4.
# ### (15점)
#
# 1부터 매개변수까지의 소수를 담은 리스트를 반환하는 함수를 작성하세요. list comprehension을 사용하세요.
#
# 함수가 잘 작동하는지 임의의 숫자를 대입하여 결과를 출력해주세요.

# %%
# Code here

# %% [markdown]
#  # Q5.
#  ### (20점)
#  정수 N을 입력 받아, 소인수분해하는 프로그램을 만들어주세요.
#
# * N의 소인수분해 결과를 한 줄에 하나씩 오름차순으로 출력합니다.

# %%
# Code here

# %% [markdown]
# # Q6.
# ### (25점)
#
# 주어진 'train.csv' 파일을 불러와주세요.
#
# Price를 예측하는 모델을 제작하기 위해 추가적인 변수를 만드려고 합니다.
#
# Price의 데이터 분포를 확인하고 1개 이상의 EDA를 통해 의견을 제시해주세요.

# %%
# Code here
